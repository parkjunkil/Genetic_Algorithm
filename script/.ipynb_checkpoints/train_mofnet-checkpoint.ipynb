# %% [markdown]
# ### Check available GPUs and set a GPU

# %%
# !nvidia-smi
# Out:
# Thu Apr 22 15:53:38 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.36.06    Driver Version: 450.36.06    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:17:00.0 Off |                  N/A |
# | 26%   42C    P5    15W / 250W |      0MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:65:00.0 Off |                  N/A |
# | 30%   46C    P5    14W / 250W |      0MiB / 11178MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce GTX 108...  Off  | 00000000:66:00.0 Off |                  N/A |
# |  0%   43C    P8     9W / 250W |    187MiB / 11176MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce GTX 1080    Off  | 00000000:B3:00.0 Off |                  N/A |
# |  0%   40C    P5    11W / 210W |      0MiB /  8119MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    2   N/A  N/A    107929      C   ...nkil/anaconda3/bin/python      185MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] ="1"

import tensorflow as tf
import tensorflow.keras as keras

tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-2-d5ab08e09d4d>:7: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
#pip install DataLoader

# %% [markdown]
# ### Import desired libraries

# %%
import pickle
from pathlib import Path
from collections import defaultdict
from itertools import cycle, permutations
from functools import partial

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import MOF-NET

# %%
from mofnet import DataLoader, MOFNet

# %% [markdown]
# ### Set name of training

# %%
training_name = "gen_3"

# %%
# !mkdir $training_name

# %% [markdown]
# ### Load working capacity data

# %%
# bar unit.
pressures = [
  1,2,5,10,20,30,35,40,50,60,70,80,90,100
]

names = ["key"] + [str(p) for p in pressures]

gcmc_data_dir = "./"

uptake_data_paths = [
    gcmc_data_dir+"cycle_1.txt",
]

wc_data_list = []
for path in uptake_data_paths:
    data = pd.read_table(path, index_col=0, header=None, names=names, sep="\s+")
    data = data["100"] - data["5"]
    wc_data_list.append(data)
wc_data = pd.concat(wc_data_list)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-6af3f3ebb5cb> in <module>
#      14 wc_data_list = []
#      15 for path in uptake_data_paths:
# ---> 16     data = pd.read_table(path, index_col=0, header=None, names=names, sep="\s+")
#      17     data = data["100"] - data["5"]
#      18     wc_data_list.append(data)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'./cycle_1.txt' does not exist: b'./cycle_1.txt'

# %%
[len(data) for data in wc_data_list]
# Out:
# [130606]

# %% [markdown]
# ### Prepare dataset

# %%
# Normalize working capacity.
data = wc_data.copy() / 100.0
# shuffle.
data = data.sample(frac=1)
data.describe()
# Out:
# count    130606.000000
# mean          0.285100
# std           0.084878
# min          -0.000076
# 25%           0.262517
# 50%           0.317170
# 75%           0.340367
# max           0.397693
# dtype: float64

# %%
# Extract maximmum values.
max_wc_dict = defaultdict(lambda: (None, -1.0))

for idx, wc in wc_data.items():
    topo = idx.split("+")[0]
    if max_wc_dict[topo][1] < wc:
        max_wc_dict[topo] = (idx, wc)

# %%
top_data = data.loc[[v[0] for v in max_wc_dict.values()]]
top_data.hist(bins=21)

top_data.describe()
# Out:
# count    1555.000000
# mean        0.337520
# std         0.055347
# min         0.000000
# 25%         0.331093
# 50%         0.350762
# 75%         0.366458
# max         0.397693
# dtype: float64

# %%
# Remove top data from dataset
data.drop(index=top_data.index, inplace=True)
data.describe()
# Out:
# count    129051.000000
# mean          0.284468
# std           0.084974
# min          -0.000076
# 25%           0.261415
# 50%           0.316700
# 75%           0.339868
# max           0.394018
# dtype: float64

# %%
# Extract training data.
n_data = len(data)
n_train = int(n_data * 0.9)

# Add top data to training set.
train_data = pd.concat([top_data, data.iloc[:n_train]])
train_data.describe()
# Out:
# count    117700.000000
# mean          0.285183
# std           0.084867
# min           0.000000
# 25%           0.262708
# 50%           0.317235
# 75%           0.340379
# max           0.397693
# dtype: float64

# %%
# Make test set.
test_data = data.iloc[n_train:]

# Remove unseen topologies.
#seen_topo = set([v.split("+")[0] for v in train_data.index])
#mask = [v.split("+")[0] in seen_topo for v in test_data.index]
#test_data = test_data[mask]

# %%
# Save train and test index.
with open("%s/train_data_index.txt"%training_name, "w") as f:
    for k in train_data.index:
        f.write(k+"\n")
        
# Save train and test index.
with open("%s/test_data_index.txt"%training_name, "w") as f:
    for k in test_data.index:
        f.write(k+"\n")

# %% [markdown]
# #### Apply resampling

# %%
# Make histogram dict by value.
hist_dict = defaultdict(lambda: 0)

bin_size = 0.001
for v in train_data:
    hist_dict[int(v/bin_size)] += 1

# Plot result.
sorted_hist_dict = sorted(hist_dict.items(), key=lambda x: x[0])
plt.bar(np.arange(len(sorted_hist_dict))*bin_size, [v[1] for v in sorted_hist_dict], width=0.9*bin_size)
plt.show()

# %%
choice_prob = np.array([1 / hist_dict[int(v/bin_size)] for v in train_data])
choice_prob = choice_prob / np.sum(choice_prob)

# %%
resampled_train_data = train_data.sample(n=500000, weights=choice_prob, replace=True)
resampled_train_data.hist(bins=100)

# %%
not_included_keys = list(set(train_data.index) - set(resampled_train_data.index))
len(not_included_keys)
# Out:
# 22683

# %%
train_data = pd.concat([
    resampled_train_data,
    train_data.loc[not_included_keys]
]).sample(frac=1)

train_data.hist(bins=100, alpha=0.5)

# %% [markdown]
# ### Prepare training loop

# %%
step = 0

# Load data loader.
data_loader = DataLoader.from_state("data_loader_state-20200116.npz")

# Make TF dataset from the data.
train_set = data_loader.make_dataset(
                np.array(train_data.index, dtype=str),
                np.array(train_data),
                batch_size=128,
            )

test_set = data_loader.make_dataset(
               np.array(test_data.index, dtype=str),
               np.array(test_data),
               batch_size=128,
           )

test_bulk = data_loader.make_dataset(
                np.array(test_data.index, dtype=str),
                np.array(test_data),
                batch_size=1000,
                repeat=False,
                shuffle=False,
            )

train_set_iter = iter(train_set)
test_set_iter = iter(test_set)

min_mse = 1e30
min_step = 0
loss_val_list = []

optimizer = tf.optimizers.Adam()

summray_dir = "%s/summary" % training_name

summary_writer_train = tf.summary.create_file_writer("%s/train" % summray_dir)
summary_writer_test = tf.summary.create_file_writer("%s/test" % summray_dir)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-e068b05cc07b> in <module>
#       2
#       3 # Load data loader.
# ----> 4 data_loader = DataLoader.from_state("data_loader_state-20200116.npz")
#       5
#       6 # Make TF dataset from the data.
#
# ~/anaconda3/lib/python3.7/site-packages/mofnet-0.0.1-py3.7.egg/mofnet/mofnet.py in from_state(filename)
#      25     @staticmethod
#      26     def from_state(filename):
# ---> 27         data = np.load(filename, allow_pickle=True)
#      28         topologies = data["topo_hash"].item()
#      29         node_hash = data["node_hash"].tolist()
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data_loader_state-20200116.npz'

# %%
# Make MOF-NET and the graph.

tf.summary.trace_on(graph=True, profiler=True)

mofnet = MOFNet()
mofnet.initialize_weights()

with summary_writer_train.as_default():
    tf.summary.trace_export(
        name="initilize_mofnet",
        profiler_outdir=".",
        step=0
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-7ceda315807f> in <module>
#       6 mofnet.initialize_weights()
#       7
# ----> 8 with summary_writer_train.as_default():
#       9     tf.summary.trace_export(
#      10         name="initilize_mofnet",
#
# NameError: name 'summary_writer_train' is not defined

# %%
# Define loss and training loop.

def calculate_loss(y_true, y_pred):
    loss = tf.reduce_mean(
        tf.square(y_true-y_pred),
    )
    
    return loss

@tf.function
def train_step(model, x, y, optimizer):
    with tf.GradientTape() as tape:
        y_pred = model(x, training=True)
        loss = calculate_loss(y_true=y, y_pred=y_pred)
        
    grads = tape.gradient(loss, model.trainable_weights)
    optimizer.apply_gradients(zip(grads, model.trainable_weights))
    
    return y_pred, loss

# %%
while True:
    if step > 200000:
        break
    
    x, y = next(train_set_iter)
    y_pred, loss = train_step(mofnet, x, y, optimizer)
    
    # No print at the first step.
    if step == 0:
        step += 1
        continue
    
    if step%100 == 0:
        test_x, test_y = next(test_set_iter)
        test_y_pred = mofnet(test_x)
        
        test_loss = calculate_loss(y_true=test_y, y_pred=test_y_pred)
        
        with summary_writer_train.as_default():
            tf.summary.scalar("mofnet/loss", loss, step=step)
            
        with summary_writer_test.as_default():
            tf.summary.scalar("mofnet/loss", test_loss, step=step)
        
    if step%1000 == 0:
        mofnet.save_weights("{n:}/mofnet-{n:}-final.h5".format(n=training_name))
        
        # Calculate validation loss.
        y_true_list = []
        y_pred_list = []
        acc_test_loss = 0
        n_test_loss = 0
        for test_x, test_y in test_bulk:
            test_y_pred = mofnet(test_x)
            test_loss = calculate_loss(y_true=test_y, y_pred=test_y_pred)
            
            acc_test_loss += test_loss
            n_test_loss += 1

        loss_val = (acc_test_loss/n_test_loss).numpy().item()
        loss_val_list.append(loss_val)

        print("[{:d}] Loss Val: {:7.4f}, MIN MSE ({:d}): {:.4f}".format(step, loss_val, min_step, min_mse))
        if loss_val < min_mse:
            min_step = step
            print("New MIN MSE: %7.4f" % loss_val)
            mofnet.save_weights("{n:}/mofnet-{n:}-min.h5".format(n=training_name))
            min_mse = loss_val
            
    step += 1
# Out:
# [1000] Loss Val:  0.0025, MIN MSE (0): 1000000000000000019884624838656.0000
# New MIN MSE:  0.0025
# [2000] Loss Val:  0.0016, MIN MSE (1000): 0.0025
# New MIN MSE:  0.0016
# [3000] Loss Val:  0.0013, MIN MSE (2000): 0.0016
# New MIN MSE:  0.0013
# [4000] Loss Val:  0.0010, MIN MSE (3000): 0.0013
# New MIN MSE:  0.0010
# [5000] Loss Val:  0.0010, MIN MSE (4000): 0.0010
# New MIN MSE:  0.0010
# [6000] Loss Val:  0.0010, MIN MSE (5000): 0.0010
# [7000] Loss Val:  0.0008, MIN MSE (5000): 0.0010
# New MIN MSE:  0.0008
# [8000] Loss Val:  0.0009, MIN MSE (7000): 0.0008
# [9000] Loss Val:  0.0008, MIN MSE (7000): 0.0008
# New MIN MSE:  0.0008
# [10000] Loss Val:  0.0007, MIN MSE (9000): 0.0008
# New MIN MSE:  0.0007
# [11000] Loss Val:  0.0010, MIN MSE (10000): 0.0007
# [12000] Loss Val:  0.0007, MIN MSE (10000): 0.0007
# New MIN MSE:  0.0007
# [13000] Loss Val:  0.0007, MIN MSE (12000): 0.0007
# New MIN MSE:  0.0007
# [14000] Loss Val:  0.0007, MIN MSE (13000): 0.0007
# [15000] Loss Val:  0.0006, MIN MSE (13000): 0.0007
# New MIN MSE:  0.0006
# [16000] Loss Val:  0.0007, MIN MSE (15000): 0.0006
# [17000] Loss Val:  0.0006, MIN MSE (15000): 0.0006
# [18000] Loss Val:  0.0006, MIN MSE (15000): 0.0006
# New MIN MSE:  0.0006
# [19000] Loss Val:  0.0007, MIN MSE (18000): 0.0006
# [20000] Loss Val:  0.0006, MIN MSE (18000): 0.0006
# [21000] Loss Val:  0.0007, MIN MSE (18000): 0.0006
# [22000] Loss Val:  0.0006, MIN MSE (18000): 0.0006
# [23000] Loss Val:  0.0006, MIN MSE (18000): 0.0006
# [24000] Loss Val:  0.0006, MIN MSE (18000): 0.0006
# [25000] Loss Val:  0.0006, MIN MSE (18000): 0.0006
# New MIN MSE:  0.0006
# [26000] Loss Val:  0.0006, MIN MSE (25000): 0.0006
# New MIN MSE:  0.0006
# [27000] Loss Val:  0.0006, MIN MSE (26000): 0.0006
# [28000] Loss Val:  0.0006, MIN MSE (26000): 0.0006
# [29000] Loss Val:  0.0006, MIN MSE (26000): 0.0006
# [30000] Loss Val:  0.0006, MIN MSE (26000): 0.0006
# [31000] Loss Val:  0.0006, MIN MSE (26000): 0.0006
# [32000] Loss Val:  0.0006, MIN MSE (26000): 0.0006
# New MIN MSE:  0.0006
# [33000] Loss Val:  0.0006, MIN MSE (32000): 0.0006
# [34000] Loss Val:  0.0006, MIN MSE (32000): 0.0006
# [35000] Loss Val:  0.0005, MIN MSE (32000): 0.0006
# New MIN MSE:  0.0005
# [36000] Loss Val:  0.0005, MIN MSE (35000): 0.0005
# [37000] Loss Val:  0.0005, MIN MSE (35000): 0.0005
# [38000] Loss Val:  0.0005, MIN MSE (35000): 0.0005
# [39000] Loss Val:  0.0006, MIN MSE (35000): 0.0005
# [40000] Loss Val:  0.0005, MIN MSE (35000): 0.0005
# [41000] Loss Val:  0.0005, MIN MSE (35000): 0.0005
# New MIN MSE:  0.0005
# [42000] Loss Val:  0.0005, MIN MSE (41000): 0.0005
# New MIN MSE:  0.0005
# [43000] Loss Val:  0.0005, MIN MSE (42000): 0.0005
# New MIN MSE:  0.0005
# [44000] Loss Val:  0.0005, MIN MSE (43000): 0.0005
# [45000] Loss Val:  0.0006, MIN MSE (43000): 0.0005
# [46000] Loss Val:  0.0005, MIN MSE (43000): 0.0005
# [47000] Loss Val:  0.0005, MIN MSE (43000): 0.0005
# New MIN MSE:  0.0005
# [48000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [49000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [50000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [51000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [52000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [53000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [54000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [55000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# [56000] Loss Val:  0.0005, MIN MSE (47000): 0.0005
# New MIN MSE:  0.0005
# [57000] Loss Val:  0.0005, MIN MSE (56000): 0.0005
# [58000] Loss Val:  0.0005, MIN MSE (56000): 0.0005
# [59000] Loss Val:  0.0005, MIN MSE (56000): 0.0005
# New MIN MSE:  0.0005
# [60000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [61000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [62000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [63000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [64000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [65000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [66000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [67000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [68000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [69000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [70000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [71000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [72000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [73000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [74000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [75000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# [76000] Loss Val:  0.0005, MIN MSE (59000): 0.0005
# New MIN MSE:  0.0005
# [77000] Loss Val:  0.0005, MIN MSE (76000): 0.0005
# [78000] Loss Val:  0.0005, MIN MSE (76000): 0.0005
# [79000] Loss Val:  0.0005, MIN MSE (76000): 0.0005
# New MIN MSE:  0.0005
# [80000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [81000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [82000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [83000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [84000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [85000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [86000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# [87000] Loss Val:  0.0005, MIN MSE (79000): 0.0005
# New MIN MSE:  0.0005
# [88000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [89000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [90000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [91000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [92000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [93000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [94000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [95000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [96000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [97000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [98000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [99000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [100000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [101000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [102000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [103000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [104000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [105000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [106000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [107000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [108000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [109000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [110000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [111000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [112000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [113000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [114000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [115000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [116000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [117000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [118000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [119000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [120000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [121000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [122000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [123000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# [124000] Loss Val:  0.0005, MIN MSE (87000): 0.0005
# New MIN MSE:  0.0005
# [125000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [126000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [127000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [128000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [129000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [130000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [131000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [132000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [133000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [134000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [135000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [136000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [137000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [138000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [139000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [140000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [141000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [142000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [143000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [144000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [145000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [146000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [147000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [148000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [149000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [150000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [151000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [152000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [153000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [154000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [155000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [156000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [157000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [158000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [159000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [160000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [161000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [162000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [163000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [164000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [165000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [166000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [167000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [168000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [169000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [170000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [171000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [172000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [173000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [174000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [175000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [176000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [177000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [178000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [179000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [180000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [181000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [182000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [183000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [184000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [185000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [186000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [187000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [188000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [189000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [190000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# [191000] Loss Val:  0.0005, MIN MSE (124000): 0.0005
# New MIN MSE:  0.0005
# [192000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [193000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [194000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [195000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [196000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [197000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [198000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [199000] Loss Val:  0.0005, MIN MSE (191000): 0.0005
# [200000] Loss Val:  0.0005, MIN MSE (191000): 0.0005

# %%
mofnet.load_weights("mofnet-{n:}-min.h5".format(n=training_name))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-bce58bd98fa1> in <module>
# ----> 1 mofnet.load_weights("mofnet-{n:}-min.h5".format(n=training_name))
#
# NameError: name 'mofnet' is not defined

# %%
y_pred = []
for x, y in test_bulk:
    _y = mofnet(x)
    y_pred += _y.numpy().reshape(-1).tolist()
y_pred = np.array(y_pred)

# %%
x = test_data*100
y = np.array(y_pred)*100
#c = [data_loader.topo_hash[v.split("+")[0]] for v in test_data.index]
#c = [max_wc_dict[v.split("+")[0]][1] for v in test_data.index]
#c=None

plt.figure(figsize=(12, 10))
plt.scatter(x, y,
            #c=c, 
            s=2, alpha=0.2)
plt.plot([0, 50], [0, 50], c="black")
plt.colorbar()
plt.show()

# %% [markdown]
# # Test Cells

# %%
path = gcmc_data_dir+"gcmc-survivors_2-cycle_2.txt"
_data = pd.read_table(path, index_col=0, header=None, names=names, sep="\s+")
_data = (_data["65"]-_data["5.8"]) / 100.0

_data_bulk = data_loader.make_dataset(
                 np.array(_data.index, dtype=str),
                 np.array(_data),
                 batch_size=1000,
                 repeat=False,
                 shuffle=False,
             )

# %%
y_pred = []
for x, y in _data_bulk:
    _y = mofnet(x)
    y_pred += _y.numpy().reshape(-1).tolist()
y_pred = np.array(y_pred)

# %%
x = _data*100
y = np.array(y_pred)*100
#c = [data_loader.topo_hash[v.split("+")[0]] for v in test_data.index]
c = [max_wc_dict[v.split("+")[0]][1] for v in _data.index]
#c=None

plt.figure(figsize=(12, 10))
plt.scatter(x, y, c=c, s=3, alpha=0.05)
plt.plot([0, 210], [0, 210], c="black")
plt.colorbar()
plt.show()

# %%
_data_bulk = data_loader.make_dataset(
                 np.array(train_data.index, dtype=str),
                 np.array(train_data),
                 batch_size=4000,
                 repeat=False,
                 shuffle=False,
             )

y_pred = []
for x, y in _data_bulk:
    _y = mofnet(x)
    y_pred += _y.numpy().reshape(-1).tolist()
y_pred = np.array(y_pred)

# %%
x = _data*100
y = np.array(y_pred)*100
#c = [data_loader.topo_hash[v.split("+")[0]] for v in test_data.index]
c = [max_wc_dict[v.split("+")[0]][1] for v in _data.index]
#c=None

plt.figure(figsize=(12, 10))
plt.scatter(x, y, c=c, s=3, alpha=0.05)
plt.plot([0, 210], [0, 210], c="black")
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-187-93d68c00830a> in <module>
#       6
#       7 plt.figure(figsize=(12, 10))
# ----> 8 plt.scatter(x, y, c=c, s=3, alpha=0.05)
#       9 plt.plot([0, 210], [0, 210], c="black")
#      10 plt.colorbar()
#
# ~/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/envs/work/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4442         y = np.ma.ravel(y)
#    4443         if x.size != y.size:
# -> 4444             raise ValueError("x and y must be the same size")
#    4445
#    4446         if s is None:
#
# ValueError: x and y must be the same size
